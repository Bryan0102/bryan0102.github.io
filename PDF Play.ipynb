# %%
import pandas as pd
import numpy as np

# %%
public_data = pd.read_csv('./movielens/ml-latest/tabula-data.csv', sep=',')
print(type(public_data))
public_data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                       Agency Name     Last Name  First Name  \
# 0                     Agency Name     Last Name  First Name
# 1  Child and Family Services Agcy        Abange   Christina
# 2    Department of Human Services         Abate       Abiye
# 3             OSSE DOT Department         Abaye    Lemlem T
# 4    Chief Financial Officer, Ofc  Abayomi-Paul     Olufemi
#
#                         Job Title                              Comp Rate  \
# 0             Job Title Comp Rate                              Type Appt
# 1                           Nurse   $90,082.00 Career Service - Reg Appt
# 2  Social Service Rep. (Bilingual  $49,570.00 Career Service - Term Appt
# 3                   BUS ATTENDANT   $18.72 Educational Service - Reg App
# 4                Senior Appraiser   $90,562.00 Career Service - Reg Appt
#
#     Type Appt Start Date
# 0  Start Date        NaN
# 1         NaN  10/7/2013
# 2         NaN  4/21/2014
# ...

# %%
public_data.shape
# Out:
# (34479, 7)

# %%
public_data.index
# Out:
# RangeIndex(start=0, stop=34479, step=1)

# %%
public_data.columns
# Out:
# Index(['Agency Name', 'Last Name', 'First Name', 'Job Title', 'Comp Rate',
#        'Type Appt', 'Start Date'],
#       dtype='object')

# %%
public_data.iloc[[1,20,200,20000]]
# Out:
#                           Agency Name      Last Name First Name  \
# 1      Child and Family Services Agcy         Abange  Christina
# 20                OSSE DOT Department     Abdelghany        Ali
# 200                Public Schools, DC          Adams      Trena
# 20000              Public Schools, DC  McCracken Ann        NaN
#
#                       Job Title                                  Comp Rate  \
# 1                         Nurse       $90,082.00 Career Service - Reg Appt
# 20       MOTOR VEHICLE OPERATOR       $24.63 Educational Service - Reg App
# 200        Teacher, Special Ed.  $100,839.00 Educational Service - Reg App
# 20000  Teacher, Early Childhood   $83,774.00 Educational Service - Reg App
#
#        Type Appt Start Date
# 1            NaN  10/7/2013
# 20           NaN  7/16/2001
# 200    8/23/2005        NaN
# 20000  8/11/2014        NaN

# %%
public_data['Comp Rate'].describe()
# Out:
# count                                    34479
# unique                                    5250
# top       $15.00 Educational Service - Temp Ap
# freq                                       961
# Name: Comp Rate, dtype: object

# %%
public_data.isnull().any()
# Out:
# Agency Name    False
# Last Name      False
# First Name      True
# Job Title       True
# Comp Rate      False
# Type Appt       True
# Start Date      True
# dtype: bool

# %%
public_data.dropna()
# Out:
#                           Agency Name     Last Name  First Name  \
# 0                         Agency Name     Last Name  First Name
# 40                 Public Schools, DC      Abdullah       Imani
# 41        Behavioral Health, Dept. of      Abdullah    Mohammed
# 42                 Public Schools, DC      Abdullah       Renee
# 43                 Public Schools, DC   Abdulmateen    Jameelah
# 44                 Public Schools, DC   Abdul-Rahim      Ayesha
# 45       Fire and Emerg. Medical Svcs  Abdul-Saboor    Muhammad
# 46     Unified Communications, Ofc of   Abdul-Wahid      Jarita
# 47                 Public Schools, DC   Abdussalaam        Alva
# 48                 Public Schools, DC  Abdus-Salaam    Khadijah
# 49       Chief Financial Officer, Ofc  Abdus-Salaam      Khalil
# 50       People's Counsel, Ofc of the  Abdus-Shahid       Talib
# 51             University of the D.C.       Abebaku      Sonnie
# 52                 Public Schools, DC         Abebe      Daniel
# ...

# %%
public_data.head(5)
# Out:
#                       Agency Name     Last Name  First Name  \
# 0                     Agency Name     Last Name  First Name
# 1  Child and Family Services Agcy        Abange   Christina
# 2    Department of Human Services         Abate       Abiye
# 3             OSSE DOT Department         Abaye    Lemlem T
# 4    Chief Financial Officer, Ofc  Abayomi-Paul     Olufemi
#
#                         Job Title                              Comp Rate  \
# 0             Job Title Comp Rate                              Type Appt
# 1                           Nurse   $90,082.00 Career Service - Reg Appt
# 2  Social Service Rep. (Bilingual  $49,570.00 Career Service - Term Appt
# 3                   BUS ATTENDANT   $18.72 Educational Service - Reg App
# 4                Senior Appraiser   $90,562.00 Career Service - Reg Appt
#
#     Type Appt Start Date
# 0  Start Date        nan
# 1         NaN  10/7/2013
# 2         NaN  4/21/2014
# 3         NaN  9/17/2001
# 4         NaN   8/1/2011

# %%
date = public_data['Start Date']

# %%
date.shape
# Out:
# (34479,)

# %%
salary = public_data['Comp Rate']

# %%
salary.shape
# Out:
# (34479,)

# %%
salary.describe()
# Out:
# count                                    34479
# unique                                    5250
# top       $15.00 Educational Service - Temp Ap
# freq                                       961
# Name: Comp Rate, dtype: object

# %%
job = public_data['Agency Name']

# %%
job.describe()
# Out:
# count                  34479
# unique                    93
# top       Public Schools, DC
# freq                    9131
# Name: Agency Name, dtype: object

# %%
salary.head()
# Out:
# 0                                Type Appt
# 1     $90,082.00 Career Service - Reg Appt
# 2    $49,570.00 Career Service - Term Appt
# 3     $18.72 Educational Service - Reg App
# 4     $90,562.00 Career Service - Reg Appt
# Name: Comp Rate, dtype: object

# %%
public_data_edu = public_data['Job Title'].str.contains('Public Schools, DC')
public_data_edu.dropna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 34449    False
# 34450    False
# 34451    False
# 34452    False
# 34453    False
# 34454    False
# 34455    False
# 34456    False
# 34457    False
# 34458    False
# 34459    False
# 34460    False
# 34461    False
# 34462    False
# 34463    False
# 34464    False
# 34465    False
# 34466    False
# 34467    False
# 34468    False
# 34469    False
# 34470    False
# 34471    False
# 34472    False
# 34473    False
# 34474    False
# 34475    False
# ...
